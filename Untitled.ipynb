# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /opt/anaconda3/lib/python3.11/site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->folium) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import random
import numpy as np
from itertools import permutations

# %%
# Coordenadas iniciais de BH (Belo Horizonte)
map_center = [-19.9208, -43.9378]

# Função para gerar coordenadas aleatórias espaçadas em torno de um ponto central
def generate_random_location(center, spread=0.05):
    return [center[0] + random.uniform(-spread, spread), center[1] + random.uniform(-spread, spread)]

# Gerar coordenadas aleatórias espaçadas para alunos
students = [{'name': f'Aluno {i+1}', 'location': generate_random_location(map_center, spread=0.03)} for i in range(6)]

# Gerar coordenadas aleatórias espaçadas para escolas
schools = [{'name': f'Escola {chr(65+i)}', 'location': generate_random_location(map_center, spread=0.03)} for i in range(2)]

# Gerar coordenadas aleatórias espaçadas para garagens
garages = [{'name': f'Garagem {i+1}', 'location': generate_random_location(map_center, spread=0.03)} for i in range(2)]

# %%
# Criar um mapa
school_map = folium.Map(location=map_center, zoom_start=14)

# Adicionar marcadores para alunos no mapa
for student in students:
    folium.Marker(location=student['location'], popup=student['name'], icon=folium.Icon(color='blue', icon='info-sign')).add_to(school_map)

# Adicionar marcadores para escolas no mapa
for school in schools:
    folium.Marker(location=school['location'], popup=school['name'], icon=folium.Icon(color='green', icon='school')).add_to(school_map)

# Adicionar marcadores para garagens no mapa
for garage in garages:
    folium.Marker(location=garage['location'], popup=garage['name'], icon=folium.Icon(color='red', icon='cog')).add_to(school_map)

# Salvar o mapa inicial em um arquivo HTML
school_map.save('initial_school_map.html')

# Exibir o mapa no Jupyter Notebook (se estiver usando Jupyter)
school_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_572cf3bbc2d9addac3325ad74f376b08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_572cf3bbc2d9addac3325ad74f376b08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_572cf3bbc2d9addac3325ad74f376b08 = L.map(
#                 &quot;map_572cf3bbc2d9addac3325ad74f376b08&quot;,
#                 {
#                     center: [-19.9208, -43.9378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b4da306676ab8b65a01bfd65e507e2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b4da306676ab8b65a01bfd65e507e2d.addTo(map_572cf3bbc2d9addac3325ad74f376b08);
#
#
#             var marker_678fe89dbfc02a22105bd8e079b6ff55 = L.marker(
#                 [-19.91568724522555, -43.94581504858325],
#                 {}
#             ).addTo(map_572cf3bbc2d9addac3325ad74f376b08);
#
#
#             var icon_0691108c8b80951dfea1433f24177abe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_678fe89dbfc02a22105bd8e079b6ff55.setIcon(icon_0691108c8b80951dfea1433f24177abe);
#
#
#         var popup_a3f13e9f6b7c646c3b56284285b38100 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0b906c9916ff2fb964b3f3688612097 = $(`&lt;div id=&quot;html_a0b906c9916ff2fb964b3f3688612097&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 1&lt;/div&gt;`)[0];
#                 popup_a3f13e9f6b7c646c3b56284285b38100.setContent(html_a0b906c9916ff2fb964b3f3688612097);
#
#
#
#         marker_678fe89dbfc02a22105bd8e079b6ff55.bindPopup(popup_a3f13e9f6b7c646c3b56284285b38100)
#         ;
#
#
#
#
#             var marker_f44b0f1d3b2b85ff792a66a3a0d223e5 = L.marker(
#                 [-19.907864744876406, -43.95307003930651],
#                 {}
#             ).addTo(map_572cf3bbc2d9addac3325ad74f376b08);
#
#
#             var icon_f1129edd859cf7f92b1f5d5780d58d8f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f44b0f1d3b2b85ff792a66a3a0d223e5.setIcon(icon_f1129edd859cf7f92b1f5d5780d58d8f);
#
#
#         var popup_f7eff866450e16876a3dd6505aa5daa0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_464e58c871e11edc812ec6f7abf304f4 = $(`&lt;div id=&quot;html_464e58c871e11edc812ec6f7abf304f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 2&lt;/div&gt;`)[0];
#                 popup_f7eff866450e16876a3dd6505aa5daa0.setContent(html_464e58c871e11edc812ec6f7abf304f4);
#
#
#
#         marker_f44b0f1d3b2b85ff792a66a3a0d223e5.bindPopup(popup_f7eff866450e16876a3dd6505aa5daa0)
#         ;
#
#
#
#
#             var marker_ad63a9d4fcc3b256849bb4aa8c4ee9af = L.marker(
#                 [-19.90024799594749, -43.952703598331176],
#                 {}
#             ).addTo(map_572cf3bbc2d9addac3325ad74f376b08);
#
#
#             var icon_fb6768af03c474e774794ea491e1ddb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad63a9d4fcc3b256849bb4aa8c4ee9af.setIcon(icon_fb6768af03c474e774794ea491e1ddb6);
#
#
#         var popup_1063603e78a4e10f062ca314e0dc4b19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d10652e230b36998e314c13a6513743 = $(`&lt;div id=&quot;html_9d10652e230b36998e314c13a6513743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 3&lt;/div&gt;`)[0];
#                 popup_1063603e78a4e10f062ca314e0dc4b19.setContent(html_9d10652e230b36998e314c13a6513743);
#
#
#
#         marker_ad63a9d4fcc3b256849bb4aa8c4ee9af.bindPopup(popup_1063603e78a4e10f062ca314e0dc4b19)
#         ;
#
#
#
#
#             var marker_447428d30d44ce5da703492d8eacebe5 = L.marker(
#                 [-19.913308236579017, -43.90839529483725],
#                 {}
#             ).addTo(map_572cf3bbc2d9addac3325ad74f376b08);
#
#
#             var icon_14338e45fb3d25f73baac34372ad2c6d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;

# %% [markdown]
# ### Função de Cálculo de Distância

# %%
def calculate_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# %% [markdown]
# ### Função de Fitness

# %%
def fitness(route):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += calculate_distance(route[i], route[i + 1])
    return total_distance

# %% [markdown]
# ### Função de Criação de Rotas

# %%
def create_route(garages, students, schools):
    stops = [garages[0]['location']] + [student['location'] for student in students] + [school['location'] for school in schools] + [garages[0]['location']]
    return stops

# %% [markdown]
# ### Função de Mutação

# %%
def mutate(route):
    idx1, idx2 = random.sample(range(1, len(route) - 1), 2)
    route[idx1], route[idx2] = route[idx2], route[idx1]
    return route

# %% [markdown]
# ## Algoritmo Genético

# %%
def genetic_algorithm(garages, students, schools, population_size=100, generations=500, mutation_rate=0.1):
    population = [create_route(garages, students, schools) for _ in range(population_size)]
    best_route = min(population, key=fitness)
    
    for generation in range(generations):
        new_population = []
        for route in population:
            if random.random() < mutation_rate:
                new_route = mutate(route[:])
                new_population.append(new_route)
            else:
                new_population.append(route)
        
        best_route_in_population = min(new_population, key=fitness)
        if fitness(best_route_in_population) < fitness(best_route):
            best_route = best_route_in_population
        
        population = new_population
    
    return best_route

# %% [markdown]
# ### Visualizar as Rotas Otimizadas

# %%
# Definir os alunos para cada escola
students_school_A = students[:3]
students_school_B = students[3:]

# Gerar rotas otimizadas
best_route_A = genetic_algorithm([garages[0]], students_school_A, [schools[0]])
best_route_B = genetic_algorithm([garages[1]], students_school_B, [schools[1]])

# Criar um novo mapa para adicionar as rotas
school_map_with_routes = folium.Map(location=map_center, zoom_start=14)

# Adicionar marcadores para alunos no novo mapa
for student in students:
    folium.Marker(location=student['location'], popup=student['name'], icon=folium.Icon(color='blue', icon='info-sign')).add_to(school_map_with_routes)

# Adicionar marcadores para escolas no novo mapa
for school in schools:
    folium.Marker(location=school['location'], popup=school['name'], icon=folium.Icon(color='green', icon='school')).add_to(school_map_with_routes)

# Adicionar marcadores para garagens no novo mapa
for garage in garages:
    folium.Marker(location=garage['location'], popup=garage['name'], icon=folium.Icon(color='red', icon='cog')).add_to(school_map_with_routes)

# Adicionar linhas representando as rotas no mapa
folium.PolyLine(best_route_A, color='red', weight=2.5, opacity=1).add_to(school_map_with_routes)
folium.PolyLine(best_route_B, color='blue', weight=2.5, opacity=1).add_to(school_map_with_routes)

# Salvar o mapa com rotas em um arquivo HTML
school_map_with_routes.save('school_routes_map.html')

# Exibir o mapa com rotas no Jupyter Notebook (se estiver usando Jupyter)
school_map_with_routes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c112ea6fd524325ab57447a6bb229d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c112ea6fd524325ab57447a6bb229d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c112ea6fd524325ab57447a6bb229d4 = L.map(
#                 &quot;map_5c112ea6fd524325ab57447a6bb229d4&quot;,
#                 {
#                     center: [-19.9208, -43.9378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec8de3f327c5fe54a942e1b028908dae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ec8de3f327c5fe54a942e1b028908dae.addTo(map_5c112ea6fd524325ab57447a6bb229d4);
#
#
#             var marker_7781e01245000e6590e0317101b0d634 = L.marker(
#                 [-19.91568724522555, -43.94581504858325],
#                 {}
#             ).addTo(map_5c112ea6fd524325ab57447a6bb229d4);
#
#
#             var icon_7bc19cf95d1f4d17ad134a53df1179f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7781e01245000e6590e0317101b0d634.setIcon(icon_7bc19cf95d1f4d17ad134a53df1179f4);
#
#
#         var popup_8646fa99a5e7f291f849a4244cacf7c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf03083854da107973680cd5113a1687 = $(`&lt;div id=&quot;html_cf03083854da107973680cd5113a1687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 1&lt;/div&gt;`)[0];
#                 popup_8646fa99a5e7f291f849a4244cacf7c1.setContent(html_cf03083854da107973680cd5113a1687);
#
#
#
#         marker_7781e01245000e6590e0317101b0d634.bindPopup(popup_8646fa99a5e7f291f849a4244cacf7c1)
#         ;
#
#
#
#
#             var marker_783ecccc26cf7f105cb7d511bbdad15f = L.marker(
#                 [-19.907864744876406, -43.95307003930651],
#                 {}
#             ).addTo(map_5c112ea6fd524325ab57447a6bb229d4);
#
#
#             var icon_ad66f2e41cbd91642fc88924be3fa880 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_783ecccc26cf7f105cb7d511bbdad15f.setIcon(icon_ad66f2e41cbd91642fc88924be3fa880);
#
#
#         var popup_4cbdc54839bac30bb3c6b5b135ed10e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_374432fe80450ef9e81ead2dca1678f4 = $(`&lt;div id=&quot;html_374432fe80450ef9e81ead2dca1678f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 2&lt;/div&gt;`)[0];
#                 popup_4cbdc54839bac30bb3c6b5b135ed10e6.setContent(html_374432fe80450ef9e81ead2dca1678f4);
#
#
#
#         marker_783ecccc26cf7f105cb7d511bbdad15f.bindPopup(popup_4cbdc54839bac30bb3c6b5b135ed10e6)
#         ;
#
#
#
#
#             var marker_a9b361e2e410c8241ff1cff38b5d549c = L.marker(
#                 [-19.90024799594749, -43.952703598331176],
#                 {}
#             ).addTo(map_5c112ea6fd524325ab57447a6bb229d4);
#
#
#             var icon_b252d6e13ea84f65105340130ea80c9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9b361e2e410c8241ff1cff38b5d549c.setIcon(icon_b252d6e13ea84f65105340130ea80c9c);
#
#
#         var popup_a9e2907ad1e0417aa781d088596c0561 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a459f55edf476929505cebcb5f9a150 = $(`&lt;div id=&quot;html_2a459f55edf476929505cebcb5f9a150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aluno 3&lt;/div&gt;`)[0];
#                 popup_a9e2907ad1e0417aa781d088596c0561.setContent(html_2a459f55edf476929505cebcb5f9a150);
#
#
#
#         marker_a9b361e2e410c8241ff1cff38b5d549c.bindPopup(popup_a9e2907ad1e0417aa781d088596c0561)
#         ;
#
#
#
#
#             var marker_eb65eb305ffe61205cb9288afbbd7667 = L.marker(
#                 [-19.913308236579017, -43.90839529483725],
#                 {}
#             ).addTo(map_5c112ea6fd524325ab57447a6bb229d4);
#
#
#             var icon_13b2f91bd84147c575af06faef79bd58 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;

# %%
# Definir os alunos para cada escola
students_school_A = students[:3]
students_school_B = students[3:]

# Gerar rotas otimizadas
best_route_A = genetic_algorithm(garages[0], students_school_A, schools[0])
best_route_B = genetic_algorithm(garages[1], students_school_B, schools[1])

# Criar um novo mapa para adicionar as rotas
school_map_with_routes = folium.Map(location=map_center, zoom_start=12)

# Adicionar marcadores para alunos no novo mapa
for student in students:
    folium.Marker(location=student['location'], popup=student['name'], icon=folium.Icon(color='blue', icon='info-sign')).add_to(school_map_with_routes)

# Adicionar marcadores para escolas no novo mapa
for school in schools:
    folium.Marker(location=school['location'], popup=school['name'], icon=folium.Icon(color='green', icon='school')).add_to(school_map_with_routes)

# Adicionar marcadores para garagens no novo mapa
for garage in garages:
    folium.Marker(location=garage['location'], popup=garage['name'], icon=folium.Icon(color='red', icon='cog')).add_to(school_map_with_routes)

# Adicionar linhas representando as rotas no mapa
folium.PolyLine(best_route_A, color='red', weight=2.5, opacity=1).add_to(school_map_with_routes)
folium.PolyLine(best_route_B, color='blue', weight=2.5, opacity=1).add_to(school_map_with_routes)

# Adicionar marcadores para os pontos de parada das rotas no mapa
for i, stop in enumerate(best_route_A):
    folium.Marker(location=stop, popup=f'Parada {i+1}', icon=folium.Icon(color='orange', icon='flag')).add_to(school_map_with_routes)

for i, stop in enumerate(best_route_B):
    folium.Marker(location=stop, popup=f'Parada {i+1}', icon=folium.Icon(color='purple', icon='flag')).add_to(school_map_with_routes)

# Salvar o mapa com rotas em um arquivo HTML
school_map_with_routes.save('school_routes_map.html')

# Exibir o mapa com rotas no Jupyter Notebook (se estiver usando Jupyter)
school_map_with_routes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 6
#       3 students_school_B = students[3:]
#       5 # Gerar rotas otimizadas
# ----> 6 best_route_A = genetic_algorithm(garages[0], students_school_A, schools[0])
#       7 best_route_B = genetic_algorithm(garages[1], students_school_B, schools[1])
#       9 # Criar um novo mapa para adicionar as rotas
#
# Cell In[9], line 2, in genetic_algorithm(garages, students, schools, population_size, generations, mutation_rate)
#       1 def genetic_algorithm(garages, students, schools, population_size=100, generations=500, mutation_rate=0.1):
# ----> 2     population = [create_route(garages, students, schools) for _ in range(population_size)]
#       3     best_route = min(population, key=fitness)
#       5     for generation in range(generations):
#
# Cell In[9], line 2, in <listcomp>(.0)
#       1 def genetic_algorithm(garages, students, schools, population_size=100, generations=500, mutation_rate=0.1):
# ----> 2     population = [create_route(garages, students, schools) for _ in range(population_size)]
#       3     best_route = min(population, key=fitness)
#       5     for generation in range(generations):
#
# Cell In[7], line 2, in create_route(garages, students, schools)
#       1 def create_route(garages, students, schools):
# ----> 2     stops = [garages[0]['location']] + [student['location'] for student in students] + [school['location'] for school in schools] + [garages[0]['location']]
#       3     return stops
#
# KeyError: 0
